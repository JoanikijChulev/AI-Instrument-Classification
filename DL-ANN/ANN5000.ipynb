# %% [markdown]
# ###**DEEP LEARNING ANN FOR 5000 SAMPLES PER CLASS.**

# %% [markdown]
# # Import Data for X and y

# %%
import pickle
import numpy as np
import pandas as pd
from time import time
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt
from scipy.stats import randint as sp_randint
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import layers, regularizers, initializers
import seaborn as sns
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.initializers import GlorotUniform
from tensorflow.keras.regularizers import l2, l1_l2
from tensorflow.keras.regularizers import l1
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow.keras.initializers import HeUniform

# %%
with open('/content/df_features_train5000.pickle', 'rb') as f:
    df_train = pickle.load(f)

# %%
df_train.head()
# Out:
#                             harmonic      mfcc_0      mfcc_1     mfcc_2  \
# bass_synthetic_116-069-127         0 -557.202515    5.753622   0.981412
# bass_synthetic_018-045-050         1 -485.269135   36.706520   1.167640
# bass_synthetic_011-040-075         0 -133.168488  111.227852 -37.395962
# bass_synthetic_076-046-050         0 -382.084808  118.211998  26.205984
# bass_synthetic_136-070-075         0 -569.803589   25.864410  14.324016
#
#                                mfcc_3     mfcc_4     mfcc_5     mfcc_6  \
# bass_synthetic_116-069-127   1.122305  -0.707372  -0.898609  -2.331761
# bass_synthetic_018-045-050   9.230674   6.142095   1.939157   0.921259
# bass_synthetic_011-040-075  53.720230 -23.686741  31.263220 -22.156073
# bass_synthetic_076-046-050  30.567608  59.839611  35.354507  12.117772
# bass_synthetic_136-070-075  12.227025   7.293108   4.873456   2.179953
#
#                                mfcc_7     mfcc_8  ...  contrast_chroma_3  \
# bass_synthetic_116-069-127  -2.756625  -2.927740  ...           0.201430
# bass_synthetic_018-045-050   2.714334   2.793374  ...           0.070766
# bass_synthetic_011-040-075  11.038134  -9.746903  ...           0.144702
# bass_synthetic_076-046-050  24.512486  22.956745  ...           0.025208
# bass_synthetic_136-070-075   1.358275   1.030449  ...           0.263737
#
#                             contrast_chroma_4  contrast_chroma_5  \
# bass_synthetic_116-069-127           0.145789           0.131073
# bass_synthetic_018-045-050           0.107711           0.089044
# bass_synthetic_011-040-075           0.892014           0.050649
# bass_synthetic_076-046-050           0.017774           0.017762
# bass_synthetic_136-070-075           0.236430           0.261355
#
#                             contrast_chroma_6  contrast_chroma_7  \
# bass_synthetic_116-069-127           0.208323           0.217919
# bass_synthetic_018-045-050           0.094892           0.183850
# bass_synthetic_011-040-075           0.004439           0.000000
# bass_synthetic_076-046-050           0.017743           0.034988
# bass_synthetic_136-070-075           0.279773           0.167548
#
#                             contrast_chroma_8  contrast_chroma_9  \
# bass_synthetic_116-069-127           0.228780           0.417073
# bass_synthetic_018-045-050           0.316033           0.617227
# bass_synthetic_011-040-075           0.186057           0.000895
# bass_synthetic_076-046-050           0.064068           0.182555
# bass_synthetic_136-070-075           0.234745           0.059394
#
#                             contrast_chroma_10  contrast_chroma_11  targets
# bass_synthetic_116-069-127            0.268706            0.291228        0
# bass_synthetic_018-045-050            0.313992            0.194215        0
# bass_synthetic_011-040-075            0.000000            0.327075        0
# bass_synthetic_076-046-050            0.841185            0.145308        0
# bass_synthetic_136-070-075            0.464480            0.081960        0
#
# [5 rows x 167 columns]

# %%
df_train.shape
# Out:
# (50000, 167)

# %%
with open('/content/df_features_test.pickle', 'rb') as f:
    df_test = pickle.load(f)

# %%
df_test.head()
# Out:
#                                  harmonic      mfcc_0      mfcc_1     mfcc_2  \
# bass_synthetic_068-049-025              1 -522.865845   46.664154  34.379803
# keyboard_electronic_001-021-127         0 -444.644012  193.890533  27.298918
# guitar_acoustic_010-066-100             0 -439.373413   59.546818   2.895078
# reed_acoustic_037-068-127               1 -372.987457   68.796799 -39.474766
# flute_acoustic_002-077-100              1 -364.779663   12.566915 -42.826504
#
#                                     mfcc_3     mfcc_4     mfcc_5     mfcc_6  \
# bass_synthetic_068-049-025       24.787596  17.420425  10.198804   4.609536
# keyboard_electronic_001-021-127  -3.689526   6.295263   8.093068  10.283858
# guitar_acoustic_010-066-100     -12.039842 -12.553241 -11.451952 -12.535439
# reed_acoustic_037-068-127       -22.089413 -50.149693 -16.565742 -29.849129
# flute_acoustic_002-077-100       19.884624 -29.598232 -21.321131 -18.308311
#
#                                     mfcc_7     mfcc_8  ...  contrast_chroma_3  \
# bass_synthetic_068-049-025        1.380600  -1.023340  ...           0.034162
# keyboard_electronic_001-021-127   6.089181   2.495069  ...           0.392218
# guitar_acoustic_010-066-100     -20.456724 -19.256969  ...           0.072573
# reed_acoustic_037-068-127       -16.627386 -17.712204  ...           0.366166
# flute_acoustic_002-077-100       -9.495085   7.672026  ...           0.037789
#
#                                  contrast_chroma_4  contrast_chroma_5  \
# bass_synthetic_068-049-025                0.035634           0.025365
# keyboard_electronic_001-021-127           0.563529           0.143236
# guitar_acoustic_010-066-100               0.091863           0.090990
# reed_acoustic_037-068-127                 0.036109           0.006731
# flute_acoustic_002-077-100                0.052419           0.910790
#
#                                  contrast_chroma_6  contrast_chroma_7  \
# bass_synthetic_068-049-025                0.019434           0.039115
# keyboard_electronic_001-021-127           0.164834           0.211634
# guitar_acoustic_010-066-100               0.840737           0.093613
# reed_acoustic_037-068-127                 0.023056           0.020713
# flute_acoustic_002-077-100                0.022027           0.030132
#
#                                  contrast_chroma_8  contrast_chroma_9  \
# bass_synthetic_068-049-025                0.092514           0.086638
# keyboard_electronic_001-021-127           0.353580           0.422365
# guitar_acoustic_010-066-100               0.048391           0.030883
# reed_acoustic_037-068-127                 0.885966           0.061736
# flute_acoustic_002-077-100                0.009579           0.028886
#
#                                  contrast_chroma_10  contrast_chroma_11  \
# bass_synthetic_068-049-025                 0.061319            0.091409
# keyboard_electronic_001-021-127            0.019230            0.009007
# guitar_acoustic_010-066-100                0.015003            0.009667
# reed_acoustic_037-068-127                  0.016221            0.002263
# flute_acoustic_002-077-100                 0.048302            0.016970
#
#                                  targets
# bass_synthetic_068-049-025             0
# keyboard_electronic_001-021-127        4
# guitar_acoustic_010-066-100            3
# reed_acoustic_037-068-127              7
# flute_acoustic_002-077-100             2
#
# [5 rows x 167 columns]

# %%
df_test.shape
# Out:
# (4096, 167)

# %%
with open('/content/df_features_valid.pickle', 'rb') as f:
    df_valid = pickle.load(f)

# %%
df_valid.head()
# Out:
#                                  harmonic      mfcc_0     mfcc_1     mfcc_2  \
# keyboard_acoustic_004-060-025           1 -475.228241  57.871929  45.420784
# bass_synthetic_033-050-100              1 -423.169067  69.134163  45.368763
# bass_synthetic_009-052-050              0 -148.793640  52.619362 -49.405605
# keyboard_electronic_003-064-127         0 -500.116241  47.007904  13.829727
# bass_synthetic_034-030-050              1 -411.500366  67.410156  39.175041
#
#                                     mfcc_3     mfcc_4     mfcc_5     mfcc_6  \
# keyboard_acoustic_004-060-025    33.626812  23.861397  16.505726  11.225737
# bass_synthetic_033-050-100       22.640657   8.431943   1.126918  -2.505024
# bass_synthetic_009-052-050       72.258690 -47.938263  37.455559 -38.765915
# keyboard_electronic_003-064-127   8.717096   3.275880  -1.387258  -5.367673
# bass_synthetic_034-030-050       55.957653  24.589691  26.617323  12.020113
#
#                                     mfcc_7     mfcc_8  ...  contrast_chroma_3  \
# keyboard_acoustic_004-060-025     6.615818   2.428365  ...           0.098993
# bass_synthetic_033-050-100       -3.276564  -2.163704  ...           0.299640
# bass_synthetic_009-052-050       19.981672 -24.018894  ...           0.054260
# keyboard_electronic_003-064-127  -7.053994  -8.340773  ...           0.079961
# bass_synthetic_034-030-050       12.310732   6.211542  ...           0.016523
#
#                                  contrast_chroma_4  contrast_chroma_5  \
# keyboard_acoustic_004-060-025             0.212848           0.251691
# bass_synthetic_033-050-100                0.032777           0.035559
# bass_synthetic_009-052-050                0.889927           0.049914
# keyboard_electronic_003-064-127           0.775507           0.115766
# bass_synthetic_034-030-050                0.055971           0.282434
#
#                                  contrast_chroma_6  contrast_chroma_7  \
# keyboard_acoustic_004-060-025             0.214841           0.128957
# bass_synthetic_033-050-100                0.048770           0.008362
# bass_synthetic_009-052-050                0.000945           0.000945
# keyboard_electronic_003-064-127           0.052649           0.165960
# bass_synthetic_034-030-050                0.750461           0.151187
#
#                                  contrast_chroma_8  contrast_chroma_9  \
# keyboard_acoustic_004-060-025             0.139373           0.083054
# bass_synthetic_033-050-100                0.048000           0.265016
# bass_synthetic_009-052-050                0.114643           0.000000
# keyboard_electronic_003-064-127           0.116424           0.088785
# bass_synthetic_034-030-050                0.031541           0.027086
#
#                                  contrast_chroma_10  contrast_chroma_11  \
# keyboard_acoustic_004-060-025              0.056506            0.099800
# bass_synthetic_033-050-100                 0.048340            0.031035
# bass_synthetic_009-052-050                 0.000000            0.434259
# keyboard_electronic_003-064-127            0.002494            0.048147
# bass_synthetic_034-030-050                 0.033757            0.028578
#
#                                  targets
# keyboard_acoustic_004-060-025          4
# bass_synthetic_033-050-100             0
# bass_synthetic_009-052-050             0
# keyboard_electronic_003-064-127        4
# bass_synthetic_034-030-050             0
#
# [5 rows x 167 columns]

# %%
df_valid.shape
# Out:
# (12678, 167)

# %%
X_train = df_train.drop(labels=['targets'], axis=1)
y_train = df_train['targets']

X_test = df_test.drop(labels=['targets'], axis=1)
y_test = df_test['targets']

X_valid = df_valid.drop(labels=['targets'], axis=1)
y_valid = df_valid['targets']

# %%
# Normalize the data

normalizer = MinMaxScaler()
scaler = StandardScaler()


X_train_normalized = normalizer.fit_transform(X_train)
X_train_normalized_standardized = scaler.fit_transform(X_train_normalized)

X_test_normalized = normalizer.fit_transform(X_test)
X_test_normalized_standardized = scaler.fit_transform(X_test_normalized)

X_valid_normalized = normalizer.fit_transform(X_valid)
X_valid_normalized_standardized = scaler.fit_transform(X_valid_normalized)

# %%
# Encoding target labels
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_valid_encoded = label_encoder.transform(y_valid)
y_test_encoded = label_encoder.transform(y_test)

# One-hot encode the target variable
y_train_one_hot = to_categorical(y_train_encoded)
y_val_one_hot = to_categorical(y_valid_encoded)
y_test_one_hot = to_categorical(y_test_encoded)

# %%
# Define input shape
input_shape = X_train.shape[1:]
print(input_shape)
# Out:
# (166,)

# %%
# Define number of classes
num_classes = len(set(y_train))
print(num_classes)
# Out:
# 10

# %% [markdown]
# # Define Confusion Matrix Function

# %%
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots(figsize=(10,10))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    #fig.tight_layout()
    return ax

# %%
class_names=np.array(['bass', 'brass', 'flute', 'guitar',
             'keyboard', 'mallet', 'organ', 'reed',
             'string', 'vocal'])

# %% [markdown]
# # ANN Simple Model

# %%
# Define the model architecture
simple_model = Sequential()
simple_model.add(Dense(64, input_shape=input_shape, activation='relu'))
simple_model.add(Dense(128, activation='relu'))
simple_model.add(Dense(256, activation='relu'))
simple_model.add(Dense(128, activation='relu'))
simple_model.add(Dense(32, activation='relu'))
simple_model.add(Dense(num_classes, activation='softmax'))

# %%
# Print model summary
simple_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                10688
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 32)                4128
#
#  dense_5 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 89386 (349.16 KB)
# Trainable params: 89386 (349.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
simple_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history_simple_model = simple_model.fit(X_train_normalized_standardized, y_train_one_hot,
                    epochs=50,
                    batch_size=32,
                    shuffle=True,
                    verbose=1,
                    validation_data=(X_valid_normalized_standardized, y_val_one_hot))
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5795 - accuracy: 0.4307 - val_loss: 1.8080 - val_accuracy: 0.3890
# Epoch 2/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.1507 - accuracy: 0.5855 - val_loss: 2.0739 - val_accuracy: 0.3889
# Epoch 3/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.9937 - accuracy: 0.6400 - val_loss: 2.0467 - val_accuracy: 0.3984
# Epoch 4/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.8866 - accuracy: 0.6807 - val_loss: 2.2227 - val_accuracy: 0.3801
# Epoch 5/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.7958 - accuracy: 0.7103 - val_loss: 2.1435 - val_accuracy: 0.4420
# Epoch 6/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.7287 - accuracy: 0.7345 - val_loss: 2.2336 - val_accuracy: 0.4148
# Epoch 7/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.6745 - accuracy: 0.7553 - val_loss: 2.6302 - val_accuracy: 0.3976
# Epoch 8/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.6240 - accuracy: 0.7724 - val_loss: 2.7349 - val_accuracy: 0.3982
# Epoch 9/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.5796 - accuracy: 0.7869 - val_loss: 2.9924 - val_accuracy: 0.3936
# Epoch 10/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.5413 - accuracy: 0.8020 - val_loss: 3.0537 - val_accuracy: 0.3889
# Epoch 11/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.5141 - accuracy: 0.8109 - val_loss: 3.0113 - val_accuracy: 0.4104
# Epoch 12/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.4916 - accuracy: 0.8204 - val_loss: 3.1414 - val_accuracy: 0.4117
# Epoch 13/50
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.4672 - accuracy: 0.8289 - val_loss: 3.2819 - val_accuracy: 0.4145
# Epoch 14/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.4392 - accuracy: 0.8383 - val_loss: 2.9743 - val_accuracy: 0.4392
# Epoch 15/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.4231 - accuracy: 0.8455 - val_loss: 3.2938 - val_accuracy: 0.4236
# Epoch 16/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.4063 - accuracy: 0.8511 - val_loss: 3.4941 - val_accuracy: 0.4341
# Epoch 17/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.3832 - accuracy: 0.8592 - val_loss: 3.8554 - val_accuracy: 0.4127
# Epoch 18/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.3721 - accuracy: 0.8640 - val_loss: 3.6224 - val_accuracy: 0.4178
# Epoch 19/50
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.3606 - accuracy: 0.8678 - val_loss: 3.9741 - val_accuracy: 0.4158
# Epoch 20/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.3446 - accuracy: 0.8746 - val_loss: 3.7531 - val_accuracy: 0.4277
# Epoch 21/50
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.3333 - accuracy: 0.8794 - val_loss: 4.1499 - val_accuracy: 0.4147
# Epoch 22/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.3210 - accuracy: 0.8825 - val_loss: 4.2136 - val_accuracy: 0.4067
# Epoch 23/50
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.3194 - accuracy: 0.8838 - val_loss: 4.2955 - val_accuracy: 0.4214
# Epoch 24/50
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.
ms/step

# %%
plot_confusion_matrix(y_test, y_pred, classes=class_names, normalize=True,
                      title='Simple ANN Model Normalized confusion matrix - 5000 samples')
# Out:
# Normalized confusion matrix
# [[0.36892052 0.01067616 0.02491103 0.13404508 0.24080664 0.06168446
#   0.03795967 0.05812574 0.04626335 0.01660735]
#  [0.02973978 0.64312268 0.01115242 0.01858736 0.03717472 0.00371747
#   0.00743494 0.07434944 0.         0.17472119]
#  [0.06111111 0.00555556 0.6        0.06111111 0.01111111 0.06666667
#   0.06111111 0.11111111 0.00555556 0.01666667]
#  [0.0904908  0.16104294 0.09969325 0.22239264 0.1702454  0.03834356
#   0.03680982 0.10122699 0.05828221 0.02147239]
#  [0.11749347 0.03002611 0.04438642 0.10966057 0.35117493 0.04699739
#   0.12924282 0.12663185 0.03002611 0.01436031]
#  [0.08910891 0.16336634 0.00990099 0.2029703  0.0990099  0.23267327
#   0.05445545 0.06930693 0.06930693 0.00990099]
#  [0.15338645 0.00199203 0.09760956 0.0438247  0.01992032 0.0498008
#   0.49203187 0.05776892 0.01394422 0.06972112]
#  [0.00425532 0.27234043 0.17021277 0.00425532 0.14468085 0.
#   0.         0.37021277 0.00851064 0.02553191]
#  [0.00980392 0.04248366 0.01633987 0.02614379 0.11437908 0.02287582
#   0.         0.11437908 0.65359477 0.        ]
#  [0.11347518 0.         0.05673759 0.         0.0070922  0.
#   0.0212766  0.09929078 0.02836879 0.67375887]]
# <Axes: title={'center': 'Simple ANN Model Normalized confusion matrix - 5000 samples'}, xlabel='Predicted label', ylabel='True label'>

# %% [markdown]
# # ANN Dropout Model

# %%
# Define the model architecture
dropout_model = Sequential()
dropout_model.add(Dense(128, input_shape=input_shape, activation='elu'))
dropout_model.add(Dense(256, activation='relu'))
dropout_model.add(Dense(512, activation='relu'))
dropout_model.add(Dropout(0.5))
dropout_model.add(Dense(256, activation='relu'))
dropout_model.add(Dense(512, activation='relu'))
dropout_model.add(Dropout(0.5))
dropout_model.add(Dense(128, activation='relu'))
dropout_model.add(Dense(64, activation='relu'))
dropout_model.add(Dense(32, activation='elu'))
dropout_model.add(Dense(num_classes, activation='softmax'))

# %%
# Print model summary
dropout_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 128)               21376
#
#  dense_7 (Dense)             (None, 256)               33024
#
#  dense_8 (Dense)             (None, 512)               131584
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_9 (Dense)             (None, 256)               131328
#
#  dense_10 (Dense)            (None, 512)               131584
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_11 (Dense)            (None, 128)               65664
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  dense_14 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 525226 (2.00 MB)
# Trainable params: 525226 (2.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
dropout_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history_dropout_model = dropout_model.fit(X_train_normalized_standardized, y_train_one_hot,
                    epochs=100,
                    batch_size=64,
                    shuffle=True,
                    verbose=1,
                    validation_data=(X_valid_normalized_standardized, y_val_one_hot))
# Out:
# Epoch 1/100
# 782/782 [==============================] - 7s 7ms/step - loss: 1.7178 - accuracy: 0.3687 - val_loss: 1.8485 - val_accuracy: 0.3610
# Epoch 2/100
# 782/782 [==============================] - 6s 7ms/step - loss: 1.3155 - accuracy: 0.5241 - val_loss: 2.1059 - val_accuracy: 0.3415
# Epoch 3/100
# 782/782 [==============================] - 5s 7ms/step - loss: 1.1593 - accuracy: 0.5818 - val_loss: 2.0306 - val_accuracy: 0.3872
# Epoch 4/100
# 782/782 [==============================] - 5s 7ms/step - loss: 1.0616 - accuracy: 0.6192 - val_loss: 2.1300 - val_accuracy: 0.3870
# Epoch 5/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.9859 - accuracy: 0.6477 - val_loss: 2.1984 - val_accuracy: 0.3751
# Epoch 6/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.9208 - accuracy: 0.6702 - val_loss: 2.1268 - val_accuracy: 0.3995
# Epoch 7/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.8710 - accuracy: 0.6881 - val_loss: 2.3171 - val_accuracy: 0.3917
# Epoch 8/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.8219 - accuracy: 0.7060 - val_loss: 2.3121 - val_accuracy: 0.3996
# Epoch 9/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.7895 - accuracy: 0.7178 - val_loss: 2.1428 - val_accuracy: 0.4006
# Epoch 10/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.7553 - accuracy: 0.7299 - val_loss: 2.3991 - val_accuracy: 0.4017
# Epoch 11/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.7299 - accuracy: 0.7380 - val_loss: 2.2390 - val_accuracy: 0.4093
# Epoch 12/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.
ms/step

# %%
plot_confusion_matrix(y_test, y_pred, classes=class_names, normalize=True,
                      title='Dropout ANN Model Normalized confusion matrix - 5000 samples')
# Out:
# Normalized confusion matrix
# [[0.34282325 0.01779359 0.04270463 0.07354686 0.34282325 0.04744958
#   0.00830368 0.09727165 0.01779359 0.00948992]
#  [0.01858736 0.71747212 0.00743494 0.01115242 0.05204461 0.
#   0.00743494 0.02230483 0.         0.16356877]
#  [0.05       0.01666667 0.62222222 0.01111111 0.         0.07222222
#   0.01666667 0.21111111 0.         0.        ]
#  [0.08435583 0.23619632 0.14570552 0.08128834 0.19631902 0.03527607
#   0.00920245 0.15337423 0.05674847 0.00153374]
#  [0.10182768 0.06527415 0.0770235  0.02610966 0.40339426 0.00913838
#   0.02480418 0.24804178 0.03002611 0.01436031]
#  [0.11386139 0.12871287 0.13861386 0.05445545 0.11386139 0.1039604
#   0.02475248 0.3019802  0.0049505  0.01485149]
#  [0.1374502  0.01593625 0.13545817 0.01593625 0.02589641 0.03984064
#   0.48406375 0.05976096 0.01792829 0.06772908]
#  [0.         0.42978723 0.18723404 0.         0.01276596 0.
#   0.00425532 0.35744681 0.00425532 0.00425532]
#  [0.02941176 0.00980392 0.02941176 0.00326797 0.12418301 0.00653595
#   0.         0.1372549  0.66013072 0.        ]
#  [0.04964539 0.         0.0141844  0.0212766  0.0070922  0.
#   0.02836879 0.21276596 0.         0.66666667]]
# <Axes: title={'center': 'Dropout ANN Model Normalized confusion matrix - 5000 samples'}, xlabel='Predicted label', ylabel='True label'>

# %% [markdown]
# # ANN Complex Model

# %%
complex_model = Sequential()
complex_model.add(Dense(256, input_shape=input_shape, activation='elu', kernel_initializer=GlorotUniform()))
complex_model.add(Dense(128, activation='relu'))
complex_model.add(Dense(256, activation='relu', kernel_initializer=HeUniform()))
complex_model.add(Dense(512, activation='leaky_relu', kernel_regularizer=tf.keras.regularizers.l1(0.01)))
complex_model.add(layers.Dropout(0.2))
complex_model.add(Dense(256, activation='relu', kernel_initializer=HeUniform()))
complex_model.add(Dense(64, activation='relu'))
complex_model.add(Dense(1024, activation='tanh',kernel_regularizer=tf.keras.regularizers.l2(0.01)))
complex_model.add(Dense(512, activation='relu'))
complex_model.add(layers.Dropout(0.2))
complex_model.add(Dense(256, activation='relu', kernel_initializer=HeUniform()))
complex_model.add(Dense(128, activation='relu'))
complex_model.add(Dense(128, activation='leaky_relu'))
complex_model.add(layers.Dropout(0.2))
complex_model.add(Dense(64, activation='elu', kernel_initializer=GlorotUniform()))
complex_model.add(Dense(num_classes, activation='softmax'))

# %%
# Print model summary
complex_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 256)               42752
#
#  dense_16 (Dense)            (None, 128)               32896
#
#  dense_17 (Dense)            (None, 256)               33024
#
#  dense_18 (Dense)            (None, 512)               131584
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_19 (Dense)            (None, 256)               131328
#
#  dense_20 (Dense)            (None, 64)                16448
#
#  dense_21 (Dense)            (None, 1024)              66560
#
#  dense_22 (Dense)            (None, 512)               524800
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_23 (Dense)            (None, 256)               131328
#
#  dense_24 (Dense)            (None, 128)               32896
#
#  dense_25 (Dense)            (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_26 (Dense)            (None, 64)                8256
#
#  dense_27 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 1169034 (4.46 MB)
# Trainable params: 1169034 (4.46 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
complex_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Define callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_accuracy', patience=8, restore_best_weights=True)

# %%
# Train the model
history_complex_model = complex_model.fit(X_train_normalized_standardized, y_train_one_hot,
                    epochs=100,
                    batch_size=64,
                    shuffle=True,
                    verbose=1,
                    validation_data=(X_valid_normalized_standardized, y_val_one_hot))
# Out:
# Epoch 1/100
# 782/782 [==============================] - 10s 10ms/step - loss: 4.4307 - accuracy: 0.2862 - val_loss: 2.1946 - val_accuracy: 0.2613
# Epoch 2/100
# 782/782 [==============================] - 8s 10ms/step - loss: 1.8459 - accuracy: 0.4084 - val_loss: 2.4593 - val_accuracy: 0.2514
# Epoch 3/100
# 782/782 [==============================] - 8s 10ms/step - loss: 1
100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9887 - accuracy: 0.7242 - val_loss: 2.6639 - val_accuracy: 0.3475
# Epoch 34/100
# 782/782 [==============================] - 8s 10ms/step - loss: 1.0034 - accuracy: 0.7256 - val_loss: 2.8342 - val_accuracy: 0.3198
# Epoch 35/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9817 - accuracy: 0.7291 - val_loss: 2.5662 - val_accuracy: 0.3184
# Epoch 36/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9666 - accuracy: 0.7336 - val_loss: 2.5855 - val_accuracy: 0.3182
# Epoch 37/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9772 - accuracy: 0.7339 - val_loss: 2.5755 - val_accuracy: 0.3316
# Epoch 38/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9552 - accuracy: 0.7375 - val_loss: 2.5220 - val_accuracy: 0.3539
# Epoch 39/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9462 - accuracy: 0.7400 - val_loss: 3.0864 - val_accuracy: 0.3363
# Epoch 40/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9482 - accuracy: 0.7424 - val_loss: 2.5956 - val_accuracy: 0.3411
# Epoch 41/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9462 - accuracy: 0.7422 - val_loss: 2.6645 - val_accuracy: 0.3327
# Epoch 42/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9367 - accuracy: 0.7462 - val_loss: 2.7316 - val_accuracy: 0.3534
# Epoch 43/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9312 - accuracy: 0.7466 - val_loss: 2.5106 - val_accuracy: 0.3590
# Epoch 44/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9314 - accuracy: 0.7478 - val_loss: 2.7007 - val_accuracy: 0.3348
# Epoch 45/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9319 - accuracy: 0.7473 - val_loss: 2.6637 - val_accuracy: 0.3404
# Epoch 46/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9160 - accuracy: 0.7530 - val_loss: 2.8541 - val_accuracy: 0.3546
# Epoch 47/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9009 - accuracy: 0.7571 - val_loss: 2.8669 - val_accuracy: 0.3168
# Epoch 48/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9143 - accuracy: 0.7552 - val_loss: 2.7306 - val_accuracy: 0.3430
# Epoch 49/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.9014 - accuracy: 0.7602 - val_loss: 2.4710 - val_accuracy: 0.3696
# Epoch 50/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8955 - accuracy: 0.7610 - val_loss: 2.8162 - val_accuracy: 0.3247
# Epoch 51/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8961 - accuracy: 0.7603 - val_loss: 2.7317 - val_accuracy: 0.3345
# Epoch 52/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8795 - accuracy: 0.7656 - val_loss: 2.7732 - val_accuracy: 0.3325
# Epoch 53/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8847 - accuracy: 0.7652 - val_loss: 2.7733 - val_accuracy: 0.3278
# Epoch 54/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8799 - accuracy: 0.7681 - val_loss: 2.5840 - val_accuracy: 0.3635
# Epoch 55/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8765 - accuracy: 0.7707 - val_loss: 2.8554 - val_accuracy: 0.3365
# Epoch 56/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8666 - accuracy: 0.7709 - val_loss: 3.1291 - val_accuracy: 0.3209
# Epoch 57/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8588 - accuracy: 0.7752 - val_loss: 2.8719 - val_accuracy: 0.3420
# Epoch 58/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8820 - accuracy: 0.7705 - val_loss: 2.7104 - val_accuracy: 0.3380
# Epoch 59/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8575 - accuracy: 0.7781 - val_loss: 2.8103 - val_accuracy: 0.3320
# Epoch 60/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8538 - accuracy: 0.7766 - val_loss: 2.8740 - val_accuracy: 0.3370
# Epoch 61/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8614 - accuracy: 0.7757 - val_loss: 2.6192 - val_accuracy: 0.3576
# Epoch 62/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.8491 - accuracy: 0.7806 - val_loss: 2.7987 - val_accuracy: 0.3421
# Epoch 63/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.
100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7601 - accuracy: 0.8175 - val_loss: 2.8973 - val_accuracy: 0.3483
# Epoch 95/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7609 - accuracy: 0.8191 - val_loss: 2.9342 - val_accuracy: 0.3378
# Epoch 96/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7623 - accuracy: 0.8184 - val_loss: 3.0771 - val_accuracy: 0.3464
# Epoch 97/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7521 - accuracy: 0.8192 - val_loss: 3.0160 - val_accuracy: 0.3366
# Epoch 98/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7429 - accuracy: 0.8228 - val_loss: 3.0823 - val_accuracy: 0.3374
# Epoch 99/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7511 - accuracy: 0.8217 - val_loss: 2.9983 - val_accuracy: 0.3473
# Epoch 100/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7671 - accuracy: 0.8210 - val_loss: 3.0713 - val_accuracy: 0.3546

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(10, 6))
plt.plot(history_complex_model.history['accuracy'], label='Training Accuracy', color='tab:blue', linewidth=2)
plt.plot(history_complex_model.history['val_accuracy'], label='Validation Accuracy', color='tab:green', linewidth=2)
plt.title('Complex Model Accuracy - 5000 samples', fontsize=16)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.8)
plt.tight_layout()
plt.show()

# %%
# Plot training & validation loss values
plt.figure(figsize=(10, 6))
plt.plot(history_complex_model.history['loss'], label='Training Loss', color='tab:red', linewidth=2)
plt.plot(history_complex_model.history['val_loss'], label='Validation Loss', color='tab:orange', linewidth=2)
plt.title('Complex Model Loss - 5000 samples', fontsize=16)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.8)
plt.tight_layout()
plt.show()

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = complex_model.evaluate(X_test_normalized_standardized, y_test_one_hot)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 128/128 [==============================] - 0s 3ms/step - loss: 3.1516 - accuracy: 0.3538
# Test Accuracy: 35.38%

# %%
# Get predictions
y_pred_probs = complex_model.predict(X_test_normalized_standardized)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 128/128 [==============================] - 0s 3ms/step

# %%
plot_confusion_matrix(y_test, y_pred, classes=class_names, normalize=True,
                      title='Complex ANN Model Normalized confusion matrix - 5000 samples')
# Out:
# Normalized confusion matrix
# [[0.28113879 0.02728351 0.06642942 0.22657177 0.20996441 0.05456702
#   0.00355872 0.0688019  0.05219454 0.00948992]
#  [0.18959108 0.65427509 0.03345725 0.01486989 0.04089219 0.00743494
#   0.         0.05576208 0.00371747 0.        ]
#  [0.07222222 0.00555556 0.61666667 0.02222222 0.03888889 0.01111111
#   0.00555556 0.22777778 0.         0.        ]
#  [0.08128834 0.25153374 0.1993865  0.10122699 0.15644172 0.01687117
#   0.00613497 0.12423313 0.04601227 0.01687117]
#  [0.15013055 0.07049608 0.12010444 0.16710183 0.28067885 0.06005222
#   0.03133159 0.0691906  0.03655352 0.01436031]
#  [0.04950495 0.13861386 0.00990099 0.38613861 0.1039604  0.08910891
#   0.01485149 0.11881188 0.08415842 0.0049505 ]
#  [0.15537849 0.         0.12151394 0.00398406 0.02589641 0.02191235
#   0.48605578 0.04581673 0.02788845 0.11155378]
#  [0.01702128 0.2212766  0.2212766  0.00425532 0.10638298 0.
#   0.         0.4        0.02978723 0.        ]
#  [0.01633987 0.09477124 0.04248366 0.0751634  0.05882353 0.00980392
#   0.         0.04248366 0.66013072 0.        ]
#  [0.23404255 0.         0.06382979 0.0070922  0.0141844  0.
#   0.03546099 0.02836879 0.0070922  0.60992908]]
# <Axes: title={'center': 'Complex ANN Model Normalized confusion matrix - 5000 samples'}, xlabel='Predicted label', ylabel='True label'>
